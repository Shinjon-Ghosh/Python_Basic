# %%
import pandas as pd
import numpy as np

reviews = pd.read_csv("winemag-data_first150k.csv", index_col=0)

# %%
reviews.columns
# Out:
# Index(['country', 'description', 'designation', 'points', 'price', 'province',
#        'region_1', 'region_2', 'variety', 'winery'],
#       dtype='object')

# %%
reviews = reviews.rename(columns = {'points':'score'})

# %%
reviews.columns
# Out:
# Index(['country', 'description', 'designation', 'score', 'price', 'province',
#        'region_1', 'region_2', 'variety', 'winery'],
#       dtype='object')

# %%
reviews.rename(index={0: 'firstEntry', 1: 'secondEntry'})
# Out:
#             country                                        description  \
# firstEntry       US  This tremendous 100% varietal wine hails from ...
# secondEntry   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2                US  Mac Watson honors the memory of a wine once ma...
# 3                US  This spent 20 months in 30% new French oak, an...
# 4            France  This is the top wine from La Bégude, named aft...
# ...             ...                                                ...
# 150925        Italy  Many people feel Fiano represents southern Ita...
# 150926       France  Offers an intriguing nose with ginger, lime an...
# 150927        Italy  This classic example comes from a cru vineyard...
# 150928       France  A perfect salmon shade, with scents of peaches...
# 150929        Italy  More Pinot Grigios should taste like this. A r...
#
#                                       designation  score  price  \
# ...

# %%
reviews.rename_axis("wines", axis='rows').rename_axis("fields", axis='columns')
# Out:
# fields country                                        description  \
# wines
# 0           US  This tremendous 100% varietal wine hails from ...
# 1        Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           US  Mac Watson honors the memory of a wine once ma...
# 3           US  This spent 20 months in 30% new French oak, an...
# 4       France  This is the top wine from La Bégude, named aft...
# ...        ...                                                ...
# 150925   Italy  Many people feel Fiano represents southern Ita...
# 150926  France  Offers an intriguing nose with ginger, lime an...
# 150927   Italy  This classic example comes from a cru vineyard...
# 150928  France  A perfect salmon shade, with scents of peaches...
# 150929   Italy  More Pinot Grigios should taste like this. A r...
#
# fields                           designation  score  price  \
# wines
# 0                          Martha's Vineyard     96  235.0
# ...

# %%
canadian_youtube = pd.read_csv("CAvideos.csv")
british_youtube = pd.read_csv("GBvideos.csv")

# %%
canadian_youtube.head()
# Out:
#       video_id trending_date  \
# 0  n1WpP7iowLc      17.14.11
# 1  0dBIkQ4Mz1M      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  d380meD0W0M      17.14.11
# 4  2Vv-BfVoq4g      17.14.11
#
#                                                title channel_title  \
# 0         Eminem - Walk On Water (Audio) ft. Beyoncé    EminemVEVO
# 1                      PLUSH - Bad Unboxing Fan Mail     iDubbbzTV
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...  Rudy Mancuso
# 3                           I Dare You: GOING BALD!?      nigahiga
# 4        Ed Sheeran - Perfect (Official Music Video)    Ed Sheeran
#
#    category_id              publish_time  \
# 0           10  2017-11-10T17:00:03.000Z
# 1           23  2017-11-13T17:00:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-12T18:01:41.000Z
# 4           10  2017-11-09T11:04:14.000Z
#
#                                                 tags     views    likes  \
# ...

# %%
canadian_youtube.columns
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description'],
#       dtype='object')

# %%
canadian_youtube.shape
# Out:
# (40881, 16)

# %%
british_youtube.head()
# Out:
#       video_id trending_date  \
# 0  Jw1Y-zhQURU      17.14.11
# 1  3s1rvMFUweQ      17.14.11
# 2  n1WpP7iowLc      17.14.11
# 3  PUTEiSjKwJU      17.14.11
# 4  rHwDegptbI4      17.14.11
#
#                                                title  \
# 0      John Lewis Christmas Ad 2017 - #MozTheMonster
# 1          Taylor Swift: …Ready for It? (Live) - SNL
# 2         Eminem - Walk On Water (Audio) ft. Beyoncé
# 3  Goals from Salford City vs Class of 92 and Fri...
# 4  Dashcam captures truck's near miss with child ...
#
#                 channel_title  category_id              publish_time  \
# 0                  John Lewis           26  2017-11-10T07:38:29.000Z
# 1         Saturday Night Live           24  2017-11-12T06:24:44.000Z
# 2                  EminemVEVO           10  2017-11-10T17:00:03.000Z
# 3  Salford City Football Club           17  2017-11-13T02:30:38.000Z
# 4            Cute Girl Videos           25  2017-11-13T01:45:13.000Z
#
# ...

# %%
british_youtube.columns
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description'],
#       dtype='object')

# %%
canadian_youtube.columns
# Out:
# Index(['video_id', 'trending_date', 'title', 'channel_title', 'category_id',
#        'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count',
#        'thumbnail_link', 'comments_disabled', 'ratings_disabled',
#        'video_error_or_removed', 'description'],
#       dtype='object')

# %%
british_youtube.shape
# Out:
# (38916, 16)

# %%
df_merged = pd.concat([canadian_youtube, british_youtube])

# %%
df_merged.shape
# Out:
# (79797, 16)

# %%
left = canadian_youtube.set_index(['title', 'trending_date'])
right = british_youtube.set_index(['title', 'trending_date'])

# %%
left.head()
# Out:
#                                                                      video_id  \
# title                                              trending_date
# Eminem - Walk On Water (Audio) ft. Beyoncé         17.14.11       n1WpP7iowLc
# PLUSH - Bad Unboxing Fan Mail                      17.14.11       0dBIkQ4Mz1M
# Racist Superman | Rudy Mancuso, King Bach & Lel... 17.14.11       5qpjK5DgCt4
# I Dare You: GOING BALD!?                           17.14.11       d380meD0W0M
# Ed Sheeran - Perfect (Official Music Video)        17.14.11       2Vv-BfVoq4g
#
#                                                                  channel_title  \
# title                                              trending_date
# Eminem - Walk On Water (Audio) ft. Beyoncé         17.14.11         EminemVEVO
# PLUSH - Bad Unboxing Fan Mail                      17.14.11          iDubbbzTV
# Racist Superman | Rudy Mancuso, King Bach & Lel... 17.14.11       Rudy Mancuso
# ...

# %%
left.shape
# Out:
# (40881, 14)

# %%
right.shape
# Out:
# (38916, 14)

# %%
df_join = left.join(right, lsuffix='_CAN', rsuffix='_UK')

# %%
df_join.shape
# Out:
# (40900, 28)

# %%
df_join.head()
# Out:
#                                                                  video_id_CAN  \
# title                                              trending_date
# !! THIS VIDEO IS NOTHING BUT PAIN !! | Getting ... 18.04.01       PNn8sECd7io
# #1 Fortnite World Rank - 2,323 Solo Wins!          18.09.03       DvPW66IFhMI
# #1 Fortnite World Rank - 2,330 Solo Wins!          18.10.03       EXEaMjFeiEk
# #1 MOST ANTICIPATED VIDEO (Timber Frame House R... 17.20.12       bYvQmusLaxw
#                                                    17.21.12       bYvQmusLaxw
#
#                                                                      channel_title_CAN  \
# title                                              trending_date
# !! THIS VIDEO IS NOTHING BUT PAIN !! | Getting ... 18.04.01                 Markiplier
# #1 Fortnite World Rank - 2,323 Solo Wins!          18.09.03             AlexRamiGaming
# #1 Fortnite World Rank - 2,330 Solo Wins!          18.10.03             AlexRamiGaming
# ...

# %%
df_join.isnull().sum()
# Out:
# video_id_CAN                      0
# channel_title_CAN                 0
# category_id_CAN                   0
# publish_time_CAN                  0
# tags_CAN                          0
# views_CAN                         0
# likes_CAN                         0
# dislikes_CAN                      0
# comment_count_CAN                 0
# thumbnail_link_CAN                0
# comments_disabled_CAN             0
# ratings_disabled_CAN              0
# video_error_or_removed_CAN        0
# description_CAN                1296
# video_id_UK                   38730
# channel_title_UK              38730
# category_id_UK                38730
# publish_time_UK               38730
# tags_UK                       38730
# views_UK                      38730
# likes_UK                      38730
# dislikes_UK                   38730
# comment_count_UK              38730
# thumbnail_link_UK             38730
# comments_disabled_UK          38730
# ratings_disabled_UK           38730
# ...
